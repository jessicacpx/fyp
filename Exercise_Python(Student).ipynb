# %% [markdown]
# # Python for Beginners

# %% [markdown]
# > This module is used as a guide for beginners to learn some fundamentals of Python prior to experience re-discovering the Higgs boson _like a physicist_ in the next module. <br>
#
# <br>
#
# **The structure of the module is:**
#
# **Section 1: Types and Variables <br>
# Section 2: Lists <br>
# Section 3: Function <br>
# Section 3a: Operators <br>
# Section 4: Dictionary <br>
# Section 5: Modules <br>
# Section 6: Plotting <br>
# Section 7: _for_ Loops**
#
# <br>

# %% [markdown]
# ![1_qa0eGxC1iHJvH8r9BROvPw.jpeg](attachment:b5ab4538-9d97-4abe-b8a2-0514a007905e.jpeg)

# %% [markdown]
# Python is a Programming language. The simplest instruction in Python is:
#
# `print()`
#
# You can print out anything like this:

# %%
#This is a cell where you can run your codes.
#Click here and press SHIFT + ENTER to run the code below.

print("Hello there!")
# Out:
# Hello there!

# %% [markdown]
# We put `#` when we want to insert comments instead of codes in the cells. `#comments` would not be run in Python.

# %%
#Run the code.
print(2)
# Out:
# 2

# %%
#Try to print something here.

# %% [markdown]
# ## Section 1: Types and Variables

# %% [markdown]
# You might get some errors or you have noticed the difference between `print("Hello there!")` and `print(2)`. <br>When should I put the **quotation marks**?
#
# Python works on object-oriented function. The one inside the parentheses of the function `print()` is called the **variable** or **object**. There are a few types of variables in Python.
#
# 1. string or str
# 2. integer or int
# 3. float
#
# **String** is an object consists of alphabets. We use `'single_quote'` or `''double_quote''` to define a string. We use double quotes especially when we have apostrophe in our string. For example: `"My sister's cat."` If we use single quote, the string will end at the apostrophe point because Python takes it as the closing single quote.
#
# Python recognises two types of numbers, the **integers** (whole numbers) and **floats** (numbers with decimal points). To identify the type of the objects, you can simply type:
#
# `type('cat')` <br>
# `type(2)` <br>
# `type(3.1)`

# %% [markdown]
# You will get an error when you print alphabet(s) without quotation marks unless you have defined the variables. Just like in Mathematics, when we learn the concept of function, $f(x)$, the variable $x$ does not have any meaning unless you let $x$ be something.
#
# Using the same example, let x be "Hello there!" and print(x).

# %%
x = "Hello there!"
print(x)
# Out:
# Hello there!

# %% [markdown]
# Look! You are printing the variable x which is defined as "Hello there!". Another example,

# %%
#Try defining some variables here. 
#Remember! Variables are case-sensitive. blue is different from bLUe.
blue = 'red'
print(blue)

bLUe = 123
print(bLUe)
# Out:
# red
# 123

# %% [markdown]
# ## Section 2: Lists

# %% [markdown]
# Imagine `list` is a like a box. It can contain any type of variables (strings or numbers). To construct a list, we use the following syntax:
#
# `list_name = []`
#
# To add variables into our list, we simply type:
#
# `list_name.append("variable1")` <br>
# `list_name.append("variable2")` <br>
# `list_name.append("variable3")`
#
# **Exercise:** <br>
# Construct a list `fav_fruits` and insert three of your favourite fruits into the list!

# %%
#Construct your list of fruits here.


#print the list of fruits too!

# %% [markdown]
# To print the second variable in the list, we type:
#
# `print(list_name[1])`
#
# Wanted to ask why it is 1 instead of 2?
#
# In Python, the numbering of index **starts from 0**. Meaning to say that, the first variable uses the index `0`, the second variable uses the index `1`...
#
# Try calling each of the fruits in your lists with indices!

# %%
#1st fruit in the list

#2nd fruit in the list

#3rd fruit in the list

# %% [markdown]
# ## Section 3: Functions

# %% [markdown]
# Functions allow us to group our codes into **blocks**. When we have lots of codes in a Python script, defining function allows us to easily read our codes blocks by blocks. Functions are also reusable, we do not need to retype certain lines of codes defined within the function, we only need to call the function and thus it saves more time and it does not make our codes look complicated.
#
# To define a function, we use the following syntax:

# %%
def function_name():
    return("Here is your result!")

# %% [markdown]
# Notice that after the first line of block title, there is an **indentation** _(a tab or four spaces)_ in the following lines which makes our codes look more tidy!
#
# To call the function, we simply insert the `function_name()`.

# %%
function_name()
# Out:
# 'Here is your result!'

# %% [markdown]
# Here is one exercise for you:
#
# Define a function such that it returns the **sum of a and b** for any vales of a and b that you can define later.

# %%
#Hint: Insert arguments a,b in the parentheses.

# %% [markdown]
# What does it return when you let a = 3 and b = 2?

# %%
#Call the function with values inside the parentheses.

# %% [markdown]
# ## Section 3a: Operators

# %% [markdown]
# There are a few types of operators that you will encounter in the next module:
# - Arithmetic Operators
# - Comparison Operators
# - Membership Operators
# - Bitwise Oprators
#
# **Arithmetic Operators**
#
# | Operator | Description |
# |----------|-------------|
# | + | Addition |
# | - | Subtraction |
# | * | Multiplication |
# | / | Division |
# | ** | Exponentation |

# %% [markdown]
# **Test your understanding...**
#
# Define a function that can compute the roots of any quadratic equation using the quadratic formula.

# %%
#define your function

# %% [markdown]
# So what are the roots of $3x^2 - 5x +2 = 0$?

# %%
#solution

# %% [markdown]
# **Comparison Operators**
#
# | Operator | Description |
# | ---------|-------------|
# |==        | Equal|
# |!=| Not equal |
# |>| Greater than|
# |<|Less than |
# |>=|Greater than or equal to|
# |<=|Less than or equal to|
#
# **Membership Operators**
#
# |Operator|Description|
# |--------|-----------|
# |a **in** b| Return True if a is present in b|
# |a **not in** b|Return True if a is not present in b|
#
# **Bitwise Operators**
#
# - Used to compare binary numbers (0,1)
#
# |Operators|Description|
# |---------|-----------|
# |&| Sets each bit to 1 if all bits are 1|
# |$|$| Sets each bit to 1 if one of the bits is 1|
# |~|Inverse each bit|

# %% [markdown]
# ## Section 4: Dictionary

# %% [markdown]
# A dictionary is a collection that contains `key:value` pairs. For example, the students in class_A are grouped into boys with names 'Ahmad', 'Chong' and girls with names 'Jess', 'Siti', 'Visha', 'Teo'. The marks recorded for girls are 60%, 90% and 85% as shown below.

# %%
class_A = {
    'boys': {'names' : ['Ahmad', 'Chong'] },
    
    'girls': {
        'names' : ['Jess', 'Siti', 'Visha', 'Teo'],
        'marks' : [60, 90, 85]
    },
}

# %% [markdown]
# Based on the above example, we have two dictionaries `'boys'` and `'girls'` inside the main dictionary `class_A`. If we look at the `'boys'`, 'names' will be our `key` and the list ['Ahmad', 'Chong'] is our `value`.
#
# When a teacher wants to know the names of the girls in Class A, he or she can simply compute:

# %%
class_A['girls']['names']
# Out:
# ['Jess', 'Siti', 'Visha', 'Teo']

# %% [markdown]
# ## Section 5: Modules

# %% [markdown]
# Before doing some mechanical work, we need to bring tools along with us so that we can complete the job easily. Same goes to programming, we need to import modules that have certain functions to help us in performing certain tasks.
#
# In Python, we import modules by writing:

# %% [markdown]
# ` import modules_name as abbreviation `

# %% [markdown]
# For example, when we want to perform numerical computing (such as computing the square root of a number) in Python, we use the $numpy$-module.
#
# Let's try to import this module!

# %%
import numpy as np

# %% [markdown]
# To use the module, we simply insert its `abbreviation` and a period `.` followed by `function_name()` found inside the module.
#
# For example, we compute the square root of 4 like this:
# `np.sqrt(4)`

# %%
#Insert your codes here.

# %% [markdown]
# ## Section 6: Plotting

# %% [markdown]
# To plot any graphs in Python, we first need to import the module `matplotlib.pyplot`
#
# To plot a histogram in Python, we write:
#
# `plt.hist(array, bins=number_of_bins, color, label)`
#
# For example:

# %%
#Importing module
import numpy as np
import matplotlib.pyplot as plt

# Creating data array
our_data = np.array([80, 65, 79, 100, 78, 78, 44, 56, 33, 22, 54, 70, 87])

# Plotting histogram
plt.hist(our_data, bins = 8, color = 'blue', label = 'boys')
plt.xlabel('Marks')
plt.ylabel('Number of students')
plt.legend()

# %%
#You can try plotting other types of data here!

# %% [markdown]
# ## Section 7: _for_ Loops

# %% [markdown]
# _for_ loops can **iterate** over the variables and print the variables following the **original sequence**.
#
# To create a _for_ loop, we type:
#
# `for` x `in` our_list/dict`:` <br>
# `    print(x)`
#
# Indentation is important in _for_ loops. Indentation usually takes a _tab_ or _four blank spaces_. Inaccurate indentation can bring us an error. To see how _for_ loops work, press SHIFT + ENTER in the following cell.

# %%
my_data = [0.12, 0.65, 2.31, 1.52, 3.56]
for ele in my_data:
    print(ele)
# Out:
# 0.12
# 0.65
# 2.31
# 1.52
# 3.56

# %% [markdown]
# Data stored for Particle Physics are not always simple. Consider if there are lists within lists, for example,
#
# `[[1,2,3],[4,5,6],[7,8,9]]`
#
# How would you print the first value of each list?

# %%
#Try yourself!

# %% [markdown]
# ![meme.jpg](attachment:2e4a2422-24a4-459d-816a-eb39adfcae5f.jpg)
#
# Still surviving? Hooray! Now you have some fundamental knowledge in Python, and of course it is time for you to proceed to the next module **(to rediscover the Higgs boson)** now, future physicist!
